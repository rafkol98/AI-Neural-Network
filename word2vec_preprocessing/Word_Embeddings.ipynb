# %% [markdown]
# Used information from to come up with my solution: https://spacy.io/usage/linguistic-features#mappings-exceptions

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import spacy

# %%
import pandas as pd
import numpy as np

# %%
# !python -m spacy download en_core_web_lg
# Out:
# ...
#      |████████████████████████████████| 827.9 MB 1.2 MB/s
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_lg')

# %%
# !python -m spacy download en
# Out:
# ...
#      |████████████████████████████████| 12.0 MB 5.5 MB/s
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.7/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.7/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')

# %%
vocab_df = pd.read_csv("/content/drive/MyDrive/St Andrews/CS5011/vocab.txt", sep=" ", header= None)

# %%
# Get only the words from the dataframe (not the weights).
words_in_vocab = vocab_df[0]

# %%
# Create an array with zeros of size vocab_size x 300 (dimensions of the word2vec data used by spacy)
weights = np.zeros((words_in_vocab.size, 300))

# %%
# Populate the weights array.
for i in range(len(words_in_vocab)):
  weights[i] = nlp(words_in_vocab[i]).vector

# %%
# Convert numpy array to dataframe to easily examine that it works as expected.
weights_df = pd.DataFrame(weights)
weights_df.insert(0,"Word",words_in_vocab, True)
weights_df[0:20]
# Out:
#           Word         0         1         2         3         4         5  \
# 0        #unk# -0.237937  0.461094  0.315947  0.120503  0.267210 -0.091710
# 1         name  0.232310 -0.024102 -0.839640 -0.426980  0.812580  0.258380
# 2          one  0.054071  0.111100 -0.145570 -0.024294  0.381100 -0.143890
# 3           of  0.060216  0.217990 -0.042490 -0.386180 -0.153880  0.034635
# 4          the  0.272040 -0.062030 -0.188400  0.023225 -0.018158  0.006719
# 5        seven  0.191490 -0.048363  0.131310 -0.240780  0.351610 -0.592220
# 6      wonders -0.023588 -0.008308 -0.120320 -0.218400 -0.425990  0.106660
# 7      ancient  0.488210 -0.378260 -0.389290 -0.130310 -0.094594  0.035006
# 8        world -0.006680  0.222380  0.277090 -0.167600  0.399340 -0.269350
# 9            .  0.012001  0.207510 -0.125780 -0.593250  0.125250  0.159750
# 10        what -0.038548  0.542520 -0.218430 -0.188550  0.073000  0.131800
# ...

# %%
# Save values in a text file.
np.savetxt(r'vocab_word2vec.txt', weights_df.values, fmt='%s')
